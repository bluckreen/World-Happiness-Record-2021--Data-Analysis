# %%
print("WELCOME TO KERALA")
# Out:
# WELCOME TO KERALA

# %%
print("HI IAM SALIHA")
# Out:
# HI IAM SALIHA

# %% [markdown]
# Create 3 variables to store your name ,age,place

# %%
name = "diana"
age = 29
place = "kozhikode"
print(name,age,place)
# Out:
# diana 29 kozhikode

# %%
name = "diana"
age = 29
place = "kozhikode"

# %%
students=["diana","riyas","fig"]

# %%
movie ={ 
    name : "Seven",
    rating : 4.5,
    actor : "Brad pitt" }
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 movie ={
#       2     name : "Seven",
# ----> 3     rating : 4.5,
#       4     actor : "Brad pitt" }
#
# NameError: name 'rating' is not defined

# %%
movie ={ 
    "name" : "Seven",
    "rating" : 4.5,
    "actor" : "Brad pitt" }

# %%
print(movie)
# Out:
# {'name': 'Seven', 'rating': 4.5, 'actor': 'Brad pitt'}

# %%
name = name
age = age
place = place
print(name,age,place)
# Out:
# diana 29 kozhikode

# %%
type(age)
# Out:
# int
