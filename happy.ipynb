# %% [markdown]
# # WORLD HAPPINESS ANALYSIS 2021

# %% [markdown]
# This project focuses on analyzing global happiness data to understand what factors contribute to a country's overall well-being. The dataset includes indicators such as GDP per capita, social support, healthy life expectancy, freedom to make life choices, generosity, and perceptions of corruption.
#
# The main objective is to study how these variables influence the happiness score of different countries and to identify which factors have the strongest impact. Using basic data analysis and visualization techniques, the project compares happiness levels across countries and regions, highlights trends, and uncovers patterns in the data.
#
# This project also aims to build an understanding of data handling, visualization, and interpretation, making it useful for developing foundational skills in data analytics.

# %% [markdown]
# ##   - Importing libraries

# %%
import pandas as pd             # data handling
import matplotlib.pyplot as plt # visualization
import seaborn as sns            # visualization

# %% [markdown]
# ## - Loading dataset

# %%
df = pd.read_csv("happiness.csv")
df
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %% [markdown]
# ## - Inspecting Data

# %%
df.head(10)
# Out:
#   Country name     Regional indicator  Ladder score  \
# 0      Finland         Western Europe         7.842
# 1      Denmark         Western Europe         7.620
# 2  Switzerland         Western Europe         7.571
# 3      Iceland         Western Europe         7.554
# 4  Netherlands         Western Europe         7.464
# 5       Norway         Western Europe         7.392
# 6       Sweden         Western Europe         7.363
# 7   Luxembourg         Western Europe         7.324
# 8  New Zealand  North America and ANZ         7.277
# 9      Austria         Western Europe         7.268
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                           0.032         7.904         7.780
# 1                           0.035         7.687         7.552
# 2                           0.036         7.643         7.500
# 3                           0.059         7.670         7.438
# 4                           0.027         7.518         7.410
# ...

# %%
df.tail(20)
# Out:
#      Country name            Regional indicator  Ladder score  \
# 129     Swaziland            Sub-Saharan Africa         4.308
# 130       Comoros            Sub-Saharan Africa         4.289
# 131         Egypt  Middle East and North Africa         4.283
# 132      Ethiopia            Sub-Saharan Africa         4.275
# 133    Mauritania            Sub-Saharan Africa         4.227
# 134    Madagascar            Sub-Saharan Africa         4.208
# 135          Togo            Sub-Saharan Africa         4.107
# 136        Zambia            Sub-Saharan Africa         4.073
# 137  Sierra Leone            Sub-Saharan Africa         3.849
# 138         India                    South Asia         3.819
# 139       Burundi            Sub-Saharan Africa         3.775
# 140         Yemen  Middle East and North Africa         3.658
# 141      Tanzania            Sub-Saharan Africa         3.623
# 142         Haiti   Latin America and Caribbean         3.615
# ...

# %%
df.sample(4)
# Out:
#              Country name            Regional indicator  Ladder score  \
# 14                Ireland                Western Europe         7.085
# 24   United Arab Emirates  Middle East and North Africa         6.561
# 100            Bangladesh                    South Asia         5.025
# 43                 Poland    Central and Eastern Europe         6.166
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 14                            0.040         7.164         7.006
# 24                            0.039         6.637         6.484
# 100                           0.046         5.115         4.934
# 43                            0.040         6.245         6.087
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 14                  11.342           0.947                   72.400
# 24                  11.085           0.844                   67.333
# 100                  8.454           0.693                   64.800
# ...

# %%
df.dtypes  # check the column data type
# Out:
# Country name                                   object
# Regional indicator                             object
# Ladder score                                  float64
# Standard error of ladder score                float64
# upperwhisker                                  float64
# lowerwhisker                                  float64
# Logged GDP per capita                         float64
# Social support                                float64
# Healthy life expectancy                       float64
# Freedom to make life choices                  float64
# Generosity                                    float64
# Perceptions of corruption                     float64
# Ladder score in Dystopia                      float64
# Explained by: Log GDP per capita              float64
# Explained by: Social support                  float64
# Explained by: Healthy life expectancy         float64
# Explained by: Freedom to make life choices    float64
# ...

# %%
df.columns # Display column names
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df.shape   # Display no. of rows and columns
# Out:
# (149, 20)

# %%
df.info() # checks information
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 20 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   Country name                                149 non-null    object
#  1   Regional indicator                          149 non-null    object
#  2   Ladder score                                149 non-null    float64
#  3   Standard error of ladder score              149 non-null    float64
#  4   upperwhisker                                149 non-null    float64
#  5   lowerwhisker                                149 non-null    float64
#  6   Logged GDP per capita                       149 non-null    float64
#  7   Social support                              149 non-null    float64
#  8   Healthy life expectancy                     149 non-null    float64
# ...

# %% [markdown]
# ## - Overview :-
# -Contains 149 countries and 20 features.
#
#
# -No missing values → clean dataset.
#
#
# -Mostly numerical data (18 columns) + 2 categorical.
#
#
# -Main variable: Ladder score (happiness score).
#
#
# -Includes factors like GDP, social support, life expectancy, freedom, generosity, and corruption.
#
#
# -Suitable for data analysis and visualization.

# %% [markdown]
# ## - Selecting columns  using  single column

# %%
df['Country name']
# Out:
# 0          Finland
# 1          Denmark
# 2      Switzerland
# 3          Iceland
# 4      Netherlands
#           ...
# 144        Lesotho
# 145       Botswana
# 146         Rwanda
# 147       Zimbabwe
# 148    Afghanistan
# Name: Country name, Length: 149, dtype: object

# %%
df['Ladder score']
# Out:
# 0      7.842
# 1      7.620
# 2      7.571
# 3      7.554
# 4      7.464
#        ...
# 144    3.512
# 145    3.467
# 146    3.415
# 147    3.145
# 148    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %% [markdown]
# ## - selecting multiple columns

# %%
df[['Regional indicator','Healthy life expectancy']]
# Out:
#      Regional indicator  Healthy life expectancy
# 0        Western Europe                   72.000
# 1        Western Europe                   72.700
# 2        Western Europe                   74.400
# 3        Western Europe                   73.000
# 4        Western Europe                   72.400
# ..                  ...                      ...
# 144  Sub-Saharan Africa                   48.700
# 145  Sub-Saharan Africa                   59.269
# 146  Sub-Saharan Africa                   61.400
# 147  Sub-Saharan Africa                   56.201
# 148          South Asia                   52.493
#
# [149 rows x 2 columns]

# %% [markdown]
# ## -  Filtering data

# %%
df[df['Ladder score']<3.000]
# Out:
#     Country name Regional indicator  Ladder score  \
# 148  Afghanistan         South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 148                           0.038         2.596         2.449
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 148                  7.695           0.463                   52.493
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 148                         0.382      -0.102                      0.924
#
#      Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 148                      2.43                              0.37
#
#      Explained by: Social support  Explained by: Healthy life expectancy  \
# 148                           0.0                                  0.126
#
#      Explained by: Freedom to make life choices  Explained by: Generosity  \
# 148                                         0.0                     0.122
#
# ...

# %%
df[df['Regional indicator']=='Sub-Saharan Africa']
# Out:
#             Country name  Regional indicator  Ladder score  \
# 49             Mauritius  Sub-Saharan Africa         6.049
# 82   Congo (Brazzaville)  Sub-Saharan Africa         5.342
# 84           Ivory Coast  Sub-Saharan Africa         5.306
# 90              Cameroon  Sub-Saharan Africa         5.142
# 91               Senegal  Sub-Saharan Africa         5.132
# 94                 Ghana  Sub-Saharan Africa         5.088
# 95                 Niger  Sub-Saharan Africa         5.074
# 97                Gambia  Sub-Saharan Africa         5.051
# 98                 Benin  Sub-Saharan Africa         5.045
# 101               Guinea  Sub-Saharan Africa         4.984
# 102         South Africa  Sub-Saharan Africa         4.956
# 111                Gabon  Sub-Saharan Africa         4.852
# 112         Burkina Faso  Sub-Saharan Africa         4.834
# 114           Mozambique  Sub-Saharan Africa         4.794
# 115              Nigeria  Sub-Saharan Africa         4.759
# ...

# %%
df[df['Country name']=='Germany']
# Out:
#    Country name Regional indicator  Ladder score  \
# 12      Germany     Western Europe         7.155
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 12                            0.04         7.232         7.077
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 12                 10.873           0.903                     72.5
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 12                         0.875       0.011                       0.46
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 12                      2.43                              1.48
#
#     Explained by: Social support  Explained by: Healthy life expectancy  \
# 12                         0.993                                  0.757
#
#     Explained by: Freedom to make life choices  Explained by: Generosity  \
# 12                                         0.6                     0.195
#
# ...

# %%
df[df['Healthy life expectancy']>71]
# Out:
#                  Country name            Regional indicator  Ladder score  \
# 0                     Finland                Western Europe         7.842
# 1                     Denmark                Western Europe         7.620
# 2                 Switzerland                Western Europe         7.571
# 3                     Iceland                Western Europe         7.554
# 4                 Netherlands                Western Europe         7.464
# 5                      Norway                Western Europe         7.392
# 6                      Sweden                Western Europe         7.363
# 7                  Luxembourg                Western Europe         7.324
# 8                 New Zealand         North America and ANZ         7.277
# 9                     Austria                Western Europe         7.268
# 10                  Australia         North America and ANZ         7.183
# 11                     Israel  Middle East and North Africa         7.157
# ...

# %% [markdown]
# ## - Filtering with Multiple Conditions

# %%
df[(df['Regional indicator']=='South Asia')& (df['lowerwhisker']>5.000)]
# Out:
#    Country name Regional indicator  Ladder score  \
# 86        Nepal         South Asia         5.269
# 88     Maldives         South Asia         5.198
#
#     Standard error of ladder score  upperwhisker  lowerwhisker  \
# 86                           0.070         5.406         5.132
# 88                           0.072         5.339         5.057
#
#     Logged GDP per capita  Social support  Healthy life expectancy  \
# 86                  8.120           0.774                   64.233
# 88                  9.826           0.913                   70.600
#
#     Freedom to make life choices  Generosity  Perceptions of corruption  \
# 86                         0.782       0.152                      0.727
# 88                         0.854       0.024                      0.825
#
#     Ladder score in Dystopia  Explained by: Log GDP per capita  \
# 86                      2.43                             0.519
# 88                      2.43                             1.115
#
# ...

# %% [markdown]
# ## - Selecting Rows

# %%
df.iloc[9] # single row
# Out:
# Country name                                         Austria
# Regional indicator                            Western Europe
# Ladder score                                           7.268
# Standard error of ladder score                         0.036
# upperwhisker                                           7.337
# lowerwhisker                                           7.198
# Logged GDP per capita                                 10.906
# Social support                                         0.934
# Healthy life expectancy                                 73.3
# Freedom to make life choices                           0.908
# Generosity                                             0.042
# Perceptions of corruption                              0.481
# Ladder score in Dystopia                                2.43
# Explained by: Log GDP per capita                       1.492
# Explained by: Social support                           1.062
# ...

# %%
df.iloc[4:10]  #portion
# Out:
#   Country name     Regional indicator  Ladder score  \
# 4  Netherlands         Western Europe         7.464
# 5       Norway         Western Europe         7.392
# 6       Sweden         Western Europe         7.363
# 7   Luxembourg         Western Europe         7.324
# 8  New Zealand  North America and ANZ         7.277
# 9      Austria         Western Europe         7.268
#
#    Standard error of ladder score  upperwhisker  lowerwhisker  \
# 4                           0.027         7.518         7.410
# 5                           0.035         7.462         7.323
# 6                           0.036         7.433         7.293
# 7                           0.037         7.396         7.252
# 8                           0.040         7.355         7.198
# 9                           0.036         7.337         7.198
#
#    Logged GDP per capita  Social support  Healthy life expectancy  \
# 4                 10.932           0.942                     72.4
# ...

# %% [markdown]
# #  #loc method

# %%
df.loc[100,'Ladder score in Dystopia']
# Out:
# np.float64(2.43)

# %% [markdown]
# ## - CLEANING DATA

# %% [markdown]
# ## - Rename column

# %%
df.rename(columns={"Country name":"Counrty","Regional indicator":"Region"},inplace=True)

# %%
df
# Out:
#          Counrty              Region  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df.head(3)
# Out:
#        Counrty          Region  Ladder score  Standard error of ladder score  \
# 0      Finland  Western Europe         7.842                           0.032
# 1      Denmark  Western Europe         7.620                           0.035
# 2  Switzerland  Western Europe         7.571                           0.036
#
#    upperwhisker  lowerwhisker  Logged GDP per capita  Social support  \
# 0         7.904         7.780                 10.775           0.954
# 1         7.687         7.552                 10.933           0.954
# 2         7.643         7.500                 11.117           0.942
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                     72.0                         0.949      -0.098
# 1                     72.7                         0.946       0.030
# 2                     74.4                         0.919       0.025
#
#    Perceptions of corruption  Ladder score in Dystopia  \
# ...

# %%
df['Ladder score'].value_counts()
# Out:
# Ladder score
# 5.929    2
# 5.477    2
# 4.854    1
# 4.984    1
# 5.074    1
#         ..
# 6.049    1
# 6.032    1
# 6.012    1
# 5.992    1
# 2.523    1
# Name: count, Length: 147, dtype: int64

# %%
"""df['engine']=pd.to_nummeric(         
    df['engine']
    .astype(str)
    .str.replace(r'[^0-9.-]','',regex=True)
    .replace('',None),
    errors='coerce'
)  """                                  # Remove text units and convert into numbers


#here this code is not neede to be executed cuz there is no missing values everything is filled
# Out:
# "df['engine']=pd.to_nummeric(         \n    df['engine']\n    .astype(str)\n    .str.replace(r'[^0-9.-]','',regex=True)\n    .replace('',None),\n    errors='coerce'\n)  "

# %% [markdown]
# ## - Dropping columns

# %%
df.drop(columns=['Standard error of ladder score'],inplace=True)

# %%
df
# Out:
#          Counrty              Region  Ladder score  upperwhisker  \
# 0        Finland      Western Europe         7.842         7.904
# 1        Denmark      Western Europe         7.620         7.687
# 2    Switzerland      Western Europe         7.571         7.643
# 3        Iceland      Western Europe         7.554         7.670
# 4    Netherlands      Western Europe         7.464         7.518
# ..           ...                 ...           ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512         3.748
# 145     Botswana  Sub-Saharan Africa         3.467         3.611
# 146       Rwanda  Sub-Saharan Africa         3.415         3.548
# 147     Zimbabwe  Sub-Saharan Africa         3.145         3.259
# 148  Afghanistan          South Asia         2.523         2.596
#
#      lowerwhisker  Logged GDP per capita  Social support  \
# 0           7.780                 10.775           0.954
# 1           7.552                 10.933           0.954
# ...

# %%
df.drop(columns=['Explained by: Social support'],inplace=True)

# %%
df.shape
# Out:
# (149, 18)

# %%
df.drop(columns=['upperwhisker'],inplace=True)

# %%
df.drop(columns=['lowerwhisker'],inplace=True)

# %%
df.drop(columns=['Explained by: Log GDP per capita','Explained by: Healthy life expectancy'],inplace=True)

# %%
df.drop(columns=['Explained by: Freedom to make life choices','Explained by: Generosity','Explained by: Perceptions of corruption'],inplace=True)

# %%
df
# Out:
#          Counrty              Region  Ladder score  Logged GDP per capita  \
# 0        Finland      Western Europe         7.842                 10.775
# 1        Denmark      Western Europe         7.620                 10.933
# 2    Switzerland      Western Europe         7.571                 11.117
# 3        Iceland      Western Europe         7.554                 10.878
# 4    Netherlands      Western Europe         7.464                 10.932
# ..           ...                 ...           ...                    ...
# 144      Lesotho  Sub-Saharan Africa         3.512                  7.926
# 145     Botswana  Sub-Saharan Africa         3.467                  9.782
# 146       Rwanda  Sub-Saharan Africa         3.415                  7.676
# 147     Zimbabwe  Sub-Saharan Africa         3.145                  7.943
# 148  Afghanistan          South Asia         2.523                  7.695
#
#      Social support  Healthy life expectancy  Freedom to make life choices  \
# ...

# %%
df.shape
# Out:
# (149, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Counrty                       149 non-null    object
#  1   Region                        149 non-null    object
#  2   Ladder score                  149 non-null    float64
#  3   Logged GDP per capita         149 non-null    float64
#  4   Social support                149 non-null    float64
#  5   Healthy life expectancy       149 non-null    float64
#  6   Freedom to make life choices  149 non-null    float64
#  7   Generosity                    149 non-null    float64
#  8   Perceptions of corruption     149 non-null    float64
#  9   Ladder score in Dystopia      149 non-null    float64
#  10  Dystopia + residual           149 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 12.9+ KB

# %% [markdown]
# ## - Handling  missing values [Cleaning Data]

# %%
df.isnull().sum()
# Out:
# Counrty                         0
# Region                          0
# Ladder score                    0
# Logged GDP per capita           0
# Social support                  0
# Healthy life expectancy         0
# Freedom to make life choices    0
# Generosity                      0
# Perceptions of corruption       0
# Ladder score in Dystopia        0
# Dystopia + residual             0
# dtype: int64

# %%
""" df['column_name'].mode() """          # to check the mode(majority) of a specific column 
"""df['column_name'].median()"""         # to check the median(central value) of a specific column
# Out:
# "df['column_name'].median()"

# %% [markdown]
# ## - Filling missing values

# %%
"""df['column_name'].fillna(df['column_name'].median(),inplace=True)"""    # to fill the missing values in a specific column 
# not necessary as the dataset has no missing values
# Out:
# "df['column_name'].fillna(df['column_name'].median(),inplace=True)"

# %%
"""df.dropna(subset=['column_name','column_name'],inplace_True)"""   # to drop rows of missing values from a column
# Out:
# "df.dropna(subset=['column_name','column_name'],inplace_True)"

# %% [markdown]
# ## - Handling Duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
"""print('Before:',df.shape)
    df=df.drop_duplicate()
    print('After:',df.shape)"""   # to drop duplicated data
# Out:
# "print('Before:',df.shape)\n    df=df.drop_duplicate()\n    print('After:',df.shape)"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149 entries, 0 to 148
# Data columns (total 11 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Counrty                       149 non-null    object
#  1   Region                        149 non-null    object
#  2   Ladder score                  149 non-null    float64
#  3   Logged GDP per capita         149 non-null    float64
#  4   Social support                149 non-null    float64
#  5   Healthy life expectancy       149 non-null    float64
#  6   Freedom to make life choices  149 non-null    float64
#  7   Generosity                    149 non-null    float64
#  8   Perceptions of corruption     149 non-null    float64
#  9   Ladder score in Dystopia      149 non-null    float64
#  10  Dystopia + residual           149 non-null    float64
# dtypes: float64(9), object(2)
# memory usage: 12.9+ KB

# %%
df.head(5)
# Out:
#        Counrty          Region  Ladder score  Logged GDP per capita  \
# 0      Finland  Western Europe         7.842                 10.775
# 1      Denmark  Western Europe         7.620                 10.933
# 2  Switzerland  Western Europe         7.571                 11.117
# 3      Iceland  Western Europe         7.554                 10.878
# 4  Netherlands  Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# ...

# %%
df.columns
# Out:
# Index(['Counrty', 'Region', 'Ladder score', 'Logged GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df.sample(4)
# Out:
#          Counrty                        Region  Ladder score  \
# 7     Luxembourg                Western Europe         7.324
# 4    Netherlands                Western Europe         7.464
# 108      Algeria  Middle East and North Africa         4.887
# 15    Costa Rica   Latin America and Caribbean         7.069
#
#      Logged GDP per capita  Social support  Healthy life expectancy  \
# 7                   11.647           0.908                   72.600
# 4                   10.932           0.942                   72.400
# 108                  9.342           0.802                   66.005
# 15                   9.880           0.891                   71.400
#
#      Freedom to make life choices  Generosity  Perceptions of corruption  \
# 7                           0.907      -0.034                      0.386
# 4                           0.913       0.175                      0.338
# 108                         0.480      -0.067                      0.752
# ...

# %%
df.shape
# Out:
# (149, 11)

# %% [markdown]
# ## - Saving modified data back to a file

# %%
df.to_csv('happiness_cleaned.csv',index=False)

# %% [markdown]
# ### Loading dataset

# %%
df_new=pd.read_csv("happiness_cleaned.csv")
df_new.head()
# Out:
#        Counrty          Region  Ladder score  Logged GDP per capita  \
# 0      Finland  Western Europe         7.842                 10.775
# 1      Denmark  Western Europe         7.620                 10.933
# 2  Switzerland  Western Europe         7.571                 11.117
# 3      Iceland  Western Europe         7.554                 10.878
# 4  Netherlands  Western Europe         7.464                 10.932
#
#    Social support  Healthy life expectancy  Freedom to make life choices  \
# 0           0.954                     72.0                         0.949
# 1           0.954                     72.7                         0.946
# 2           0.942                     74.4                         0.919
# 3           0.983                     73.0                         0.955
# 4           0.942                     72.4                         0.913
#
#    Generosity  Perceptions of corruption  Ladder score in Dystopia  \
# ...

# %% [markdown]
# # > Summary Statistics

# %%
df['Region'].mode()
# Out:
# 0    Sub-Saharan Africa
# Name: Region, dtype: object

# %%
df['Ladder score'].median()
# Out:
# 5.534

# %%
df['Freedom to make life choices'].median()
# Out:
# 0.804

# %%
df['Ladder score in Dystopia'].median()
# Out:
# 2.43

# %%
df['Healthy life expectancy'].median()
# Out:
# 66.603

# %% [markdown]
# ## - Average(mean)

# %%
print("Ladder_score : ",df_new['Ladder score'].mean())
print("Generosity : ",df_new['Generosity'].mean())
# Out:
# Ladder_score :  5.532838926174497
# Generosity :  -0.015134228187919463

# %%
print("Freedom to make life choices : ",df_new['Freedom to make life choices'].mean())
# Out:
# Freedom to make life choices :  0.7915973154362417

# %%
print("Social support : ",df_new['Social support'].mean())
print("Dystopia + residual  : ",df_new['Dystopia + residual'].mean())
print("GDP : ",df_new['Logged GDP per capita'].mean())
# Out:
# Social support :  0.8147449664429529
# Dystopia + residual  :  2.430328859060403
# GDP :  9.432208053691276

# %% [markdown]
# ## - Median

# %%
print("Ladder_score : ",df_new['Ladder score'].median())
print("Generosity : ",df_new['Generosity'].median())
print("Freedom to make life choices : ",df_new['Freedom to make life choices'].median())
print("Social support : ",df_new['Social support'].median())
print("Dystopia + residual  : ",df_new['Dystopia + residual'].median())
print("GDP : ",df_new['Logged GDP per capita'].median())
# Out:
# Ladder_score :  5.534
# Generosity :  -0.036
# Freedom to make life choices :  0.804
# Social support :  0.832
# Dystopia + residual  :  2.509
# GDP :  9.569

# %% [markdown]
# ## - Mode

# %%
print("Major_Region : ",df_new['Region'].mode())
# Out:
# Major_Region :  0    Sub-Saharan Africa
# Name: Region, dtype: object

# %% [markdown]
# ## - Standard Deviation (std)

# %%
print("Perceptions of corruption : ",df_new['Perceptions of corruption'].std())
print("Ladder_score : ",df_new['Ladder score'].std())
print("Generosity : ",df_new['Generosity'].std())
# Out:
# Perceptions of corruption :  0.17922631911280354
# Ladder_score :  1.0739235658235977
# Generosity :  0.15065670021779695

# %% [markdown]
# #### - mean,median,std and mode of the whole columns

# %%
df_new.select_dtypes(include='number').mean()
# Out:
# Ladder score                     5.532839
# Logged GDP per capita            9.432208
# Social support                   0.814745
# Healthy life expectancy         64.992799
# Freedom to make life choices     0.791597
# Generosity                      -0.015134
# Perceptions of corruption        0.727450
# Ladder score in Dystopia         2.430000
# Dystopia + residual              2.430329
# dtype: float64

# %%
df_new.select_dtypes(include='number').median()
# Out:
# Ladder score                     5.534
# Logged GDP per capita            9.569
# Social support                   0.832
# Healthy life expectancy         66.603
# Freedom to make life choices     0.804
# Generosity                      -0.036
# Perceptions of corruption        0.781
# Ladder score in Dystopia         2.430
# Dystopia + residual              2.509
# dtype: float64

# %%
df_new.select_dtypes(include='number').std()
# Out:
# Ladder score                    1.073924e+00
# Logged GDP per capita           1.158601e+00
# Social support                  1.148890e-01
# Healthy life expectancy         6.762043e+00
# Freedom to make life choices    1.133318e-01
# Generosity                      1.506567e-01
# Perceptions of corruption       1.792263e-01
# Ladder score in Dystopia        5.347044e-15
# Dystopia + residual             5.376452e-01
# dtype: float64

# %%
df_new.select_dtypes(include='object').mode()
# Out:
#          Counrty              Region
# 0    Afghanistan  Sub-Saharan Africa
# 1        Albania                 NaN
# 2        Algeria                 NaN
# 3      Argentina                 NaN
# 4        Armenia                 NaN
# ..           ...                 ...
# 144    Venezuela                 NaN
# 145      Vietnam                 NaN
# 146        Yemen                 NaN
# 147       Zambia                 NaN
# 148     Zimbabwe                 NaN
#
# [149 rows x 2 columns]

# %%
df_new.describe()
# Out:
#        Ladder score  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.532839               9.432208        0.814745
# std        1.073924               1.158601        0.114889
# min        2.523000               6.635000        0.463000
# 25%        4.852000               8.541000        0.750000
# 50%        5.534000               9.569000        0.832000
# 75%        6.255000              10.421000        0.905000
# max        7.842000              11.647000        0.983000
#
#        Healthy life expectancy  Freedom to make life choices  Generosity  \
# count               149.000000                    149.000000  149.000000
# mean                 64.992799                      0.791597   -0.015134
# std                   6.762043                      0.113332    0.150657
# min                  48.478000                      0.382000   -0.288000
# ...

# %%
df_new.describe(include=object)
# Out:
#         Counrty              Region
# count       149                 149
# unique      149                  10
# top     Finland  Sub-Saharan Africa
# freq          1                  36

# %% [markdown]
# ## -  Summary Insights
#
#
#   * The count is the same (149) for all columns- no missing values.
#   * Ladder score in Dystopia has almost no variation- mean ,min,persentiles and max are of the same value.
#   * The average happiness score (Ladder score) is 5.53, with values ranging from 2.52 to 7.84. The standard deviation (≈1.07) indicates a  moderate spread, showing variation in happiness levels across countries.
# * The dataset shows moderate variation across economic, social, and health-related factors, all of which contribute to differences in happiness levels across countries.
# * Since the mean and median are nearly equal for most columns, the data appears to be fairly symmetric with low skewness.
# * The standard deviation values are not very high, indicating that most data points are not widely spread from the mean.
# * GDP per capita,Life expectancy have a wider range, meaning greater variation across countries.
# * Overall, the dataset shows moderate variability and fairly consistent distribution patterns across most features.
# * The Country column has 149 unique values, which means each country appears only once in the dataset (no repetition).
# * The Region column has 10 unique categories, showing that countries are grouped into 10 different regions.
# * The most frequent region is Sub-Saharan Africa, with a frequency of 36 countries, indicating it has the highest representation in the dataset.

# %% [markdown]
# #  DATA VISUALIZATION

# %% [markdown]
# ## - Univariate Analysis

# %% [markdown]
# ### -> Histogram

# %% [markdown]
# * ### Distribution of continues numerical data

# %%
import matplotlib.pyplot as plt

df_num = df_new.copy()
df_num.drop(columns=['Region', 'Counrty'], inplace=True)

# Better: adjust figsize based on number of columns
n_cols = len(df_num.columns)
figsize = (20, 4 * ((n_cols + 3) // 4))  # Dynamically sized

df_num.hist(figsize=figsize, bins=20, edgecolor='black')
plt.tight_layout()
plt.show()

# %% [markdown]
# #### - Insights
#   * Ladder score is roughly bell-shaped, peaking between 5 and 6, with most countries falling in the moderate happiness range.
#
# * Logged GDP per capita shows two visible peaks around 9.5 and 10.5, suggesting a divide between middle-income and high-income countries.
#
# * Social support is heavily concentrated at higher values between 0.85 and 0.95, meaning most countries report strong social bonds.
#
# * Healthy life expectancy histogram reveals a bimodal pattern with two distinct peaks.
#
# * Freedom to make life choices is mostly clustered between 0.7 and 0.9, indicating that most countries enjoy a relatively high level of personal freedom.
#
# * Generosity is centered around 0 and ranges from -0.25 to 0.5, showing that charitable behavior varies widely and many countries report near-zero or negative generosity scores.
#
# * Perceptions of corruption are heavily concentrated at higher values between 0.7 and 0.9 and it's left skewed , meaning most people around the world perceive significant corruption in their governments.
#
# * Ladder score in Dystopia histogram shows nearly constant values clustered around 2.43.
#
# * Dystopia plus residual ranges from 1.0 to 3.5 with a peak around 2.5.

# %% [markdown]
# ## -> Boxplot

# %%
for col in df_num.columns:
    plt.figure(figsize=(6,4))
    plt.boxplot(df_num[col])
    plt.title(col)
    plt.show()

# %% [markdown]
# #### - Insights
#  * Ladder score has median approximately 5.5 to 6.5 with lower outliers on the left tail.
#
# * Logged GDP per capita shows near-symmetric distribution with moderate interquartile range and no extreme outliers.
#
# * Social support has higher median value with shorter lower quartile range and minimal outliers on low end.
#
# * Healthy life expectancy displays bimodal distribution with two distinct median clusters across observations.
#
# * Freedom to make life choices shows compressed interquartile range concentrated in upper quartiles with few lower outliers.
#
# * Generosity has very low median with negative skew and long upper tail containing multiple high outliers.
#
# * Perceptions of corruption displays wide interquartile range indicating high variance across all observations.
#
# * Ladder score in Dystopia has zero variance with median, quartiles, and all values equal to constant 2.43.
#
# * Dystopia plus residual shows median around 2.0 with symmetrical spread and moderate variance both directions.
#
# * Ladder score's lower outliers represent observations falling below Dystopia baseline despite adequate GDP.
#
# * Social support's compact upper quartile aligns with Ladder score's happiest observations showing strong covariance.
#
# * Perceptions of corruption's lower quartile outliers correspond to happier Ladder score observations.
#
# * Freedom's narrow interquartile range suggests low variance with most observations clustering near median.
#
# * Dystopia plus residual exhibits both positive and negative residuals relative to baseline with mean near zero.

# %% [markdown]
# ### ->Pie Chart

# %%
region_counts = df_new["Region"].value_counts()

plt.figure(figsize=(8,6))
plt.pie(region_counts, labels=region_counts.index, autopct='%1.1f%%') #displaying percentages on the pie chart.

plt.title("Count of Countries per Region")
plt.tight_layout()
plt.show()

# %% [markdown]
# #### - Insights
# * Sub-Saharan Africa has the highest representation at 24.2 percent of all countries.
#
# * Western Europe follows with 14.1 percent of countries in the dataset.
#
# * Latin America and Caribbean ranks third at 13.4 percent.
#
# * Central and Eastern Europe and Middle East and North Africa are tied at 11.4 percent each.
#
# * North America and ANZ has the lowest representation at only 2.7 percent.

# %% [markdown]
# ## - Bivariate Analysis

# %% [markdown]
# ### -> Scatter Plot

# %%
sns.scatterplot(x='Ladder score', y='Logged GDP per capita', data=df_new)

plt.xlabel("Ladder score")
plt.ylabel("Logged GDP per capita")
plt.title("Ladder score vs GDP")

plt.show()

# %% [markdown]
# #### - Insights
# * There is a clear positive relationship between GDP and happiness — as ladder scores rise from 3 to 8, logged GDP increases from around 7 to 11.5.
#
# * However, the wide scatter of points shows that several countries have high GDP but moderate happiness, confirming that wealth alone does not guarantee wellbeing.

# %%
sns.scatterplot(x='Ladder score', y='Social support', data=df_num)

plt.xlabel("Ladder score")
plt.ylabel("Social support")
plt.title("Ladder score vs Social support")

plt.show()

# %% [markdown]
# #### - Insights
# * There is a clear positive relationship between social support and happiness — as ladder scores rise from 2.5 to 8, social support increases from around 0.45 to 0.95.
#
# * The scatter is wide at lower happiness scores but tightens above 6.5, meaning the happiest countries almost always report consistently high social support.

# %%
sns.scatterplot(x='Ladder score', y='Healthy life expectancy', data=df_num)

plt.xlabel("Ladder score")
plt.ylabel("Healthy life expectancy")
plt.title("Ladder score vs Healthy life expectancy")

plt.show()

# %% [markdown]
# #### - Insights
# * There is a clear positive relationship between healthy life expectancy and happiness — as ladder scores rise from 2.5 to 8, healthy life expectancy increases from around 52% to 75%.
#
# * The scatter is wide in the middle range but clusters more tightly above a ladder score of 6 and 7, meaning the happiest countries consistently maintain high healthy life expectancy.

# %%
sns.scatterplot(x='Ladder score', y='Perceptions of corruption', data=df_num)

plt.xlabel("Ladder score")
plt.ylabel("Perceptions of corruption")
plt.title("Ladder score vs Perceptions of corruption")

plt.show()

# %% [markdown]
# #### - Insights
# * There is a negative relationship between corruption and happiness — as ladder scores rise, corruption perception generally drops from around 0.9 to below 0.2.
#
# * However, the wide scatter across all happiness levels shows that many countries with moderate happiness still report very high corruption, meaning reduced corruption only clearly shows among the happiest nations above a ladder score of 7.

# %%
sns.scatterplot(x='Logged GDP per capita', y='Social support', data=df_num)

plt.xlabel("Logged GDP per capita")
plt.ylabel("Social support")
plt.title("Logged GDP per capita vs Social support")

plt.show()

# %% [markdown]
# #### - Insights
# * There is a clear positive relationship between GDP and social support — as logged GDP rises from 7 to 11.5, social support increases from around 0.5 to 0.95.
#
# * The scatter is wide at lower GDP levels but tightens above 10, meaning wealthier nations consistently report stronger social support with very few exceptions.

# %%
sns.scatterplot(x='Logged GDP per capita', y='Healthy life expectancy', data=df_num)

plt.xlabel("Logged GDP per capita")
plt.ylabel("Healthy life expectancy")
plt.title("Logged GDP per capita vs Healthy life expectancy")

plt.show()

# %% [markdown]
# #### - Insights
# * There is a strong positive relationship between GDP and healthy life expectancy — as logged GDP rises from 7 to 11.5, healthy life expectancy increases from around 53% to 75%.
#
# * The scatter is wide at lower GDP levels but tightens significantly above 10, meaning wealthier nations consistently achieve higher and more predictable health outcomes.

# %%
sns.scatterplot(x='Social support', y='Healthy life expectancy', data=df_num)

plt.xlabel("Social support")
plt.ylabel("Healthy life expectancy")
plt.title("Social support vs Healthy life expectancy")

plt.show()

# %% [markdown]
# #### - Insights
# * There is a clear positive relationship between social support and healthy life expectancy — as social support rises from 0.45 to 1.0, healthy life expectancy increases from around 52% to 75%.
#
# * The scatter is wide at lower social support levels but clusters more tightly above 0.85, meaning countries with the strongest social bonds consistently achieve higher and more stable health outcomes.

# %% [markdown]
# ### -> Bar Plot

# %%
for col in df_num.columns:
    plt.figure(figsize=(10, 6))
    
    sns.barplot(
        x='Region',
        y=col,          # ✅ use the column from loop
        data=df,
        hue='Region',   # needed for palette
        palette='viridis',
        legend=False
    )
    
    plt.xticks(rotation=45)
    plt.title(f"Average {col} by Region", fontsize=14)
    plt.xlabel("Region")
    plt.ylabel(col)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### - Insights
# * North America & ANZ is the happiest region with a score of 7.1, while Sub-Saharan Africa and South Asia are the least happy at 4.5.
# * GDP per capita and social support are the biggest contributors to happiness across all regions.
# * Countries with low corruption tend to have higher happiness scores, as seen in North America and Western Europe.
# * Regions with higher life expectancy consistently report higher happiness levels.
# * East Asia has a high GDP but only average happiness, likely due to cultural factors, high corruption perception, and low personal freedom.
# * The happiest regions all share a combination of high GDP, strong social support, low corruption, long life expectancy, and high freedom.
# * Finland, Denmark, Iceland, Israel, and the Netherlands are typically the top 5 happiest countries in the world.
# * Sub-Saharan Africa has the lowest happiness score, pulled down by the lowest GDP and life expectancy among all regions.
# * Social support has one of the strongest links to happiness — regions with stronger social bonds consistently report higher wellbeing.
# * Generosity is the most unpredictable happiness factor and has the least consistent impact across regions.
# * The dystopia baseline score is identical across all regions as it is a fixed reference point used in the World Happiness Report methodology, not real variation.

# %% [markdown]
# #### -> Line plot

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Logged GDP per capita', y='Healthy life expectancy', data=df_new)


plt.xlabel('Logged GDP per capita')
plt.ylabel('Healthy life expectancy')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### - Insights
# * The overall trend follows a positive slope, meaning healthy life expectancy increases steadily as GDP rises.
# * The pattern resembles a heteroscedastic relationship — variance is high at lower GDP and decreases as GDP increases, which is a common pattern in economic health data.
# * Overall the data is right-skewed in terms of health outcomes, with a few low-GDP countries dragging the lower end down while high-GDP nations cluster consistently at the top.

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Logged GDP per capita', y='Social support', data=df_new)


plt.xlabel('Logged GDP per capita')
plt.ylabel('Social support')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### - Insights
# * As GDP rises, social support increases from around 0.5 to 0.95, showing that wealthier nations tend to have stronger social bonds.
#
# * The curve is highly volatile in the middle-income range but stabilizes above GDP 10, meaning richer countries consistently maintain high social support levels.

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(x='Ladder score', y='Healthy life expectancy', data=df_new)


plt.xlabel('Ladder score')
plt.ylabel('Healthy life expectancy')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# #### - Insights
# * As happiness scores rise from 3 to 8, healthy life expectancy increases from around 53% to 72%, showing a clear positive relationship between health and happiness.
#
# * The curve is highly volatile between ladder scores of 4.5 and 6.5 but stabilizes above 7, meaning the happiest countries consistently maintain healthy life expectancy around 70 to 75%.

# %% [markdown]
# ## - Multivariate Analysis

# %% [markdown]
# ### ->Heat Map

# %%
plt.figure(figsize=(12,8))
num_cols = df_new.select_dtypes(include='number').columns
sns.heatmap(df_num.corr(),
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# %% [markdown]
# #### - Insights
# * GDP per capita has the strongest correlation with ladder score at 0.79, making it the top economic predictor of wellbeing.
# * Healthy life expectancy follows closely at 0.77, showing that healthier populations are significantly happier.
# * Social support correlates at 0.76 with happiness, confirming it as one of the most reliable drivers of wellbeing.
# * Freedom to make life choices has a moderate positive correlation of 0.61, meaning personal autonomy meaningfully contributes to happiness.
# * Generosity has almost no correlation with happiness at -0.02, making it the weakest and least reliable factor.
# * Perceptions of corruption negatively correlate with happiness at -0.42, meaning higher corruption is clearly linked to lower happiness.
# * GDP and healthy life expectancy are strongly linked to each other at 0.86, suggesting wealthier nations naturally invest more in health.
# * Freedom and corruption have a negative correlation of -0.40, meaning countries with more personal freedom tend to have lower corruption.
# * Dystopia + residual correlates with happiness at 0.49, capturing the unexplained portion of happiness not covered by the six main factors.
# * Overall, GDP, health, and social support form the strongest trio of happiness predictors, while generosity has virtually no impact.

# %% [markdown]
# #  Conclusion

# %% [markdown]
# Based on the analysis, the dataset is clean and well-structured, allowing accurate exploration using **data cleaning**, **univariate analysis**, **bivariate analysis**, and **data visualization** techniques.
#
# The results indicate that the **Ladder score (happiness)** shows moderate variation across countries and is strongly influenced by factors such as **GDP per capita, social support, and healthy life expectancy**. Most variables display **fairly symmetric distributions with moderate spread**, suggesting stable patterns, while factors like **generosity and corruption** vary more widely.
#
# Key observations such as the **bimodal distribution of life expectancy** and the presence of **outliers in happiness scores** highlight global inequalities. Additionally, the consistent value of the **Dystopia baseline** helps in comparing deviations across countries.
#
# Overall, the analysis confirms that **happiness is multi-dimensional**, shaped by a combination of economic, social, and health-related factors, while also demonstrating practical skills in **data handling, visualization, and interpretation**.
