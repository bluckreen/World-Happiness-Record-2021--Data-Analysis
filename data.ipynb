# %%
print("hello")
# Out:
# hello

# %%
print("faaaahhhh")
# Out:
# faaaahhhh

# %%
print("affirmation")
# Out:
# affirmation

# %%
print("This is the end"
"Hold your breath and count to ten")
# Out:
# This is the endHold your breath and count to ten

# %%
import pandas
import numpy
import matplotlib
import seaborn

# %%
import numpy

# %%
import matplotlib

# %%
import seaborn

# %% [markdown]
# analysis

# %%
import pandas

# %% [markdown]
# # data
